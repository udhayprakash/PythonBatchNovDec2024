# %% [markdown]
# # iter() protocol
#
#     Iterator objects
#         - iterator is an immutable, disposable and lazy object
#         - designed for builtin iterable objects
#         - can't be indexed
#         - stores the state
#         - used for large data handling
#         - values can be retrieved by
#             - .next() attribute in python 2.x
#             - next() function in python 3.x
#             - applying for loop

# %%
alpha = ["a", "e", "i", "o", "u"]
print(f"alpha       : {type(alpha)} {alpha}")
print(f"len(alpha)  : {len(alpha)}")
# Out:
# alpha       : <class 'list'> ['a', 'e', 'i', 'o', 'u']
# len(alpha)  : 5

# %%
# Indexing
print(f"alpha[2]    : {alpha[2]}")

# slicing
print(f"alpha[2:5]  : {alpha[2:5]}")
# Out:
# alpha[2]    : i
# alpha[2:5]  : ['i', 'o', 'u']

# %%
# Creating Iterator from a list --> List Iterator
alpha_it = iter(alpha)
print(f"alpha_it       : {type(alpha_it)} {alpha_it}")
# len(alpha_it)        # TypeError: object of type 'list_iterator' has no len()
# alpha_it[2]          # TypeError: 'list_iterator' object is not subscriptable
# alpha_it[2:5]        # TypeError: 'list_iterator' object is not subscriptable
# alpha_it.append(12)  # AttributeError: 'list_iterator' object has no attribute 'append'
# Out:
# alpha_it       : <class 'list_iterator'> <list_iterator object at 0x768dcd3d3eb0>

# %%
# Method 1: iterate over the object
for ech_ele in alpha_it:
    print(ech_ele)
# Out:
# a
# e
# i
# o
# u

# %%
# Method 2: Convert to other iterables
print("list(alpha_it)", list(alpha_it))
# Out:
# list(alpha_it) []

# %%
alpha_it = iter(alpha)
print("list(alpha_it)", list(alpha_it))

alpha_it = iter(alpha)
print("tuple(alpha_it)", tuple(alpha_it))

alpha_it = iter(alpha)
print("set(alpha_it)", set(alpha_it))

alpha_it = iter(alpha)
print("str(alpha_it)", str(alpha_it))
# Out:
# list(alpha_it) ['a', 'e', 'i', 'o', 'u']
# tuple(alpha_it) ('a', 'e', 'i', 'o', 'u')
# set(alpha_it) {'i', 'o', 'a', 'u', 'e'}
# str(alpha_it) <list_iterator object at 0x768dcd3d3eb0>

# %%
# list to iterator -> list iterator
alpha = ["a", "e", "i", "o", "u"]
print(type(alpha), alpha)


alpha_it = iter(alpha)
print(type(alpha_it), alpha_it)
# Out:
# <class 'list'> ['a', 'e', 'i', 'o', 'u']
# <class 'list_iterator'> <list_iterator object at 0x768dcd3a3340>

# %%
# tuple to iterator -> tuple iterator
alpha = ("a", "e", "i", "o", "u")
print(type(alpha), alpha)

alpha_it = iter(alpha)
print(type(alpha_it), alpha_it)
# Out:
# <class 'tuple'> ('a', 'e', 'i', 'o', 'u')
# <class 'tuple_iterator'> <tuple_iterator object at 0x768dcd3a2020>

# %%
# set to iterator -> set iterator
alpha = {"a", "e", "i", "o", "u"}
print(type(alpha), alpha)

alpha_it = iter(alpha)
print(type(alpha_it), alpha_it)  # set_iterator
# Out:
# <class 'set'> {'u', 'i', 'o', 'e', 'a'}
# <class 'set_iterator'> <set_iterator object at 0x768dcd3dd5c0>

# %%
alpha = {"a": 1, "e": 2, "i": 3, "o": 4}
print(type(alpha), alpha)

alpha_it = iter(alpha)
print(type(alpha_it), alpha_it)
# Out:
# <class 'dict'> {'a': 1, 'e': 2, 'i': 3, 'o': 4}
# <class 'dict_keyiterator'> <dict_keyiterator object at 0x768dcd71a070>

# %%
alpha_it = iter(alpha.keys())
print(type(alpha_it), alpha_it)  # dict_keyiterator

alpha_it = iter(alpha.values())
print(type(alpha_it), alpha_it)  # dict_valueiterator

alpha_it = iter(alpha.items())
print(type(alpha_it), alpha_it)  # dict_itemiterator
# Out:
# <class 'dict_keyiterator'> <dict_keyiterator object at 0x768dcd39f8d0>
# <class 'dict_valueiterator'> <dict_valueiterator object at 0x768dcd71a070>
# <class 'dict_itemiterator'> <dict_itemiterator object at 0x768dcd39f8d0>

# %%
language = "python"
language_it = iter(language)
print(type(language_it), language_it)  # str_iterator
# Out:
# <class 'str_ascii_iterator'> <str_ascii_iterator object at 0x768dcd3d3a90>

# %% [markdown]
# Iterators
#
#         - To get values from an iterator objects
#             1. Iterate over it
#                     - for loop
#                     - converting to other iterables
#                         - list(), tuple(), set(), dict()
#             2. To apply next()
#                 - will result in one element at a time

# %%
a = ["foo", "bar", "baz"]

itr = iter(a)
for value in itr:
    print("value", value)
# Out:
# value foo
# value bar
# value baz

# %%
itr

# %%
list(itr)
# Out:
# []

# %%
itr = iter(a)
print("\n", itr)
# Out:
#  <list_iterator object at 0x768dcca26ce0>

# %%
print("\nitr.__next__()", itr.__next__())
print("next(itr)     ", next(itr))
print("next(itr)     ", next(itr))
# Out:
# itr.__next__() foo
# next(itr)      bar
# next(itr)      baz

# %%
try:
    print("next(itr)     ", next(itr))
except StopIteration as ex:
    print(repr(ex))
# Out:
# StopIteration()

# %%
print("\nReassigning")

itr = iter(a)
while True:
    try:
        print("next(itr)     ", next(itr))
    except StopIteration as ex:
        print(repr(ex))
        break
# Out:
# Reassigning
# next(itr)      foo
# next(itr)      bar
# next(itr)      baz
# StopIteration()

# %% [markdown]
# # cProfiler

# %%
import cProfile

# %%
help(cProfile)
# Out:
# Help on module cProfile:
#
# NAME
#     cProfile
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/cprofile.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Python interface for the 'lsprof' profiler.
#     Compatible with the 'profile' module.
#
# CLASSES
#     _lsprof.Profiler(builtins.object)
#         Profile
#
#     class Profile(_lsprof.Profiler)
#      |  Profile(timer=None, timeunit=None, subcalls=True, builtins=True)
#      |
#      |  Builds a profiler object using the specified timer function.
#      |  The default timer is a fast built-in one based on real time.
#      |  For custom timer functions returning integers, timeunit can
#      |  be a float specifying a scale (i.e. how long each integer unit
#      |  is, in seconds).
#      |
#      |  Method resolution order:
#      |      Profile
#      |      _lsprof.Profiler
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __enter__(self)
#      |
#      |  __exit__(self, *exc_info)
#      |
#      |  create_stats(self)
#      |
#      |  dump_stats(self, file)
#      |
#      |  print_stats(self, sort=-1)
#      |
#      |  run(self, cmd)
#      |
#      |  runcall(self, func, /, *args, **kw)
#      |      # This method is more useful to profile a single function call.
#      |
#      |  runctx(self, cmd, globals, locals)
#      |
#      |  snapshot_stats(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from _lsprof.Profiler:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  clear(...)
#      |      clear()
#      |
#      |      Clear all profiling information collected so far.
#      |
#      |  disable(...)
#      |      disable()
#      |
#      |      Stop collecting profiling information.
#      |
#      |  enable(...)
#      |      enable(subcalls=True, builtins=True)
#      |
#      |      Start collecting profiling information.
#      |      If 'subcalls' is True, also records for each function
#      |      statistics separated according to its current caller.
#      |      If 'builtins' is True, records the time spent in
#      |      built-in functions separately from their caller.
#      |
#      |  getstats(self, /)
#      |      list of profiler_entry objects.
#      |
#      |      getstats() -> list of profiler_entry objects
#      |
#      |      Return all information collected by the profiler.
#      |      Each profiler_entry is a tuple-like object with the
#      |      following attributes:
#      |
#      |          code          code object
#      |          callcount     how many times this was called
#      |          reccallcount  how many times called recursively
#      |          totaltime     total time in this entry
#      |          inlinetime    inline time in this entry (not in subcalls)
#      |          calls         details of the calls
#      |
#      |      The calls attribute is either None or a list of
#      |      profiler_subentry objects:
#      |
#      |          code          called code object
#      |          callcount     how many times this is called
#      |          reccallcount  how many times this is called recursively
#      |          totaltime     total time spent in this call
#      |          inlinetime    inline time (not in further subcalls)
#
# FUNCTIONS
#     run(statement, filename=None, sort=-1)
#         Run statement under profiler optionally saving results in filename
#
#         This function takes a single argument that can be passed to the
#         "exec" statement, and an optional file name.  In all cases this
#         routine attempts to "exec" its first argument and gather profiling
#         statistics from the execution. If no file name is present, then this
#         function automatically prints a simple profiling report, sorted by the
#         standard name string (file/line/function-name) that is presented in
#         each line.
#
#     runctx(statement, globals, locals, filename=None, sort=-1)
#         Run statement under profiler, supplying your own globals and locals,
#         optionally saving results in filename.
#
#         statement and filename have the same semantics as profile.run
#
# DATA
#     __all__ = ['run', 'runctx', 'Profile']
#
# FILE
#     /usr/local/python/3.12.1/lib/python3.12/cProfile.py

# %%
dir(cProfile)
# Out:
# ['Profile',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_lsprof',
#  '_pyprofile',
#  'importlib',
#  'io',
#  'label',
#  'main',
#  'run',
#  'runctx']

# %%
exec("20+10")

# %%
eval("20+10")
# Out:
# 30

# %%
cProfile.run("20+10")
# Out:
#          3 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# ncalls : Shows the number of calls made
#
# tottime: Total time taken by the given function. Note that the time made in calls to sub-functions are excluded.
#
# percall: Total time / No of calls. ( remainder is left out )
#
# cumtime: Unlike tottime, this includes time spent in this and all subfunctions that the higher-level function calls. It is most useful and is accurate for recursive functions.
#
# The percall following cumtime is calculated as the quotient of cumtime divided by primitive calls. The primitive calls include all the calls that were not included through recursion.

# %%
cProfile.run(
    """
result = []
for i in range(9):
    result.append(i)
"""
)
# Out:
#          12 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         9    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
cProfile.run(
    """
result = [i for i in range(9)]
"""
)
# Out:
#          3 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
cProfile.run(
    """
result = list(range(9))
""",
    filename=None,
    sort=-1,
)
# Out:
#          3 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# Code containing multiple functions
def create_array():
    arr = []
    for i in range(0, 400000):
        arr.append(i)


def print_statement():
    print("Array created successfully")


def main():
    create_array()
    print_statement()


cProfile.run("main()")
# Out:
# Array created successfully
#          400655 function calls (400635 primitive calls) in 0.109 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.004    0.004    0.021    0.021 1140210951.py:12(main)
#         1    0.010    0.010    0.017    0.017 1140210951.py:2(create_array)
#         1    0.000    0.000    0.000    0.000 1140210951.py:8(print_statement)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.021    0.021 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         1    0.000    0.000    0.002    0.002 asyncio.py:200(_handle_events)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         1    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         1    0.000    0.000    0.000    0.000 base_events.py:1889(_timer_handle_cancelled)
#         5    0.003    0.001    0.058    0.012 base_events.py:1894(_run_once)
#         9    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         1    0.000    0.000    0.000    0.000 base_events.py:445(create_future)
#         5    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         1    0.000    0.000    0.000    0.000 base_events.py:717(is_closed)
#         8    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         1    0.000    0.000    0.000    0.000 base_events.py:740(call_later)
#         1    0.000    0.000    0.000    0.000 base_events.py:764(call_at)
#         3    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         4    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         1    0.000    0.000    0.000    0.000 base_events.py:835(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         1    0.000    0.000    0.033    0.033 decorator.py:229(fun)
#        29    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#        15    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         7    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#        29    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#         1    0.000    0.000    0.000    0.000 events.py:107(__init__)
#         1    0.000    0.000    0.000    0.000 events.py:151(cancel)
#         5    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         1    0.000    0.000    0.000    0.000 events.py:68(cancel)
#       7/3    0.001    0.000    0.001    0.000 events.py:82(_run)
#         1    0.000    0.000    0.000    0.000 futures.py:311(_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#         1    0.000    0.000    0.033    0.033 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.028    0.028 history.py:833(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         1    0.000    0.000    0.029    0.029 history.py:845(writeout_cache)
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         1    0.000    0.000    0.000    0.000 iostream.py:118(_run_event_pipe_gc)
#         1    0.000    0.000    0.000    0.000 iostream.py:127(_event_pipe_gc)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         2    0.000    0.000    0.001    0.000 iostream.py:157(_handle_event)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#         2    0.000    0.000    0.001    0.000 iostream.py:276(<lambda>)
#         2    0.000    0.000    0.001    0.000 iostream.py:278(_really_send)
#         2    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#         2    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:655(write)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         3    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         3    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         5    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         1    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#       4/1    0.000    0.000    0.000    0.000 selectors.py:451(select)
#        15    0.000    0.000    0.000    0.000 socket.py:626(send)
#         2    0.000    0.000    0.000    0.000 socket.py:703(send_multipart)
#         2    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#         2    0.000    0.000    0.000    0.000 tasks.py:653(sleep)
#         4    0.000    0.000    0.000    0.000 threading.py:1153(_wait_for_tstate_lock)
#         4    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         4    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         6    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         6    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#        24    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:556(_run_callback)
#         2    0.000    0.000    0.002    0.001 zmqstream.py:583(_handle_events)
#         2    0.001    0.000    0.002    0.001 zmqstream.py:624(_handle_recv)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         3    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#     79/75    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        28    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         2    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         8    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.017    0.008    0.028    0.014 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#       7/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    400005    0.042    0.000    0.042    0.000 {method 'append' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#       4/1    0.031    0.008    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#        10    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       6/4    0.000    0.000    0.002    0.000 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         3    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
cProfile.run("main()", sort=True)  # Order is based on tottime, percall, ncalls
# Out:
# Array created successfully
#          400621 function calls (400609 primitive calls) in 0.109 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    400006    0.044    0.000    0.044    0.000 {method 'append' of 'list' objects}
#         1    0.040    0.040    0.069    0.069 1140210951.py:2(create_array)
#         2    0.013    0.007    0.025    0.012 {method '__exit__' of 'sqlite3.Connection' objects}
#       2/1    0.005    0.002    0.103    0.103 {built-in method builtins.exec}
#         1    0.003    0.003    0.072    0.072 1140210951.py:12(main)
#       3/1    0.003    0.001    0.000    0.000 selectors.py:451(select)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#        15    0.000    0.000    0.000    0.000 socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:655(write)
#        16    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 socket.py:703(send_multipart)
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         5    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#     83/79    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#        31    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#         2    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#         3    0.000    0.000    0.011    0.004 base_events.py:1894(_run_once)
#       5/3    0.000    0.000    0.006    0.002 {method 'run' of '_contextvars.Context' objects}
#         8    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#       5/3    0.000    0.000    0.006    0.002 events.py:82(_run)
#         1    0.000    0.000    0.000    0.000 poll.py:80(poll)
#        31    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         1    0.000    0.000    0.025    0.025 history.py:845(writeout_cache)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:583(_handle_events)
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         2    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         1    0.000    0.000    0.025    0.025 history.py:833(_writeout_input_cache)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         2    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         4    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.006    0.006 kernelbase.py:302(poll_control_queue)
#         8    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 1140210951.py:8(print_statement)
#         8    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:624(_handle_recv)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         2    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:324(_flush)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:427(flush)
#         3    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         2    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:276(<lambda>)
#         4    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 base_events.py:835(call_soon_threadsafe)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#         5    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:556(_run_callback)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:468(update_flag)
#         1    0.000    0.000    0.006    0.006 futures.py:394(_call_set_state)
#         3    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.025    0.025 decorator.py:229(fun)
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         1    0.000    0.000    0.000    0.000 asyncio.py:200(_handle_events)
#       4/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         9    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         1    0.000    0.000    0.025    0.025 history.py:55(only_when_enabled)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         1    0.000    0.000    0.006    0.006 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#         2    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         9    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#        28    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         2    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#         1    0.000    0.000    0.072    0.072 <string>:1(<module>)
#         5    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         2    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         4    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         2    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         5    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         1    0.000    0.000    0.000    0.000 poll.py:31(register)
#         1    0.000    0.000    0.006    0.006 _base.py:537(set_result)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         5    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         1    0.000    0.000    0.000    0.000 threading.py:1153(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:659(_check_closed)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:717(is_closed)

# %%
cProfile.run("main()", sort="ncalls")  # Order is ncalls
# Out:
# Array created successfully
#          400620 function calls (400606 primitive calls) in 0.111 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    400006    0.041    0.000    0.041    0.000 {method 'append' of 'list' objects}
#     83/79    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        31    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#        31    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#        28    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        16    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#        15    0.003    0.000    0.005    0.000 socket.py:626(send)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         9    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         9    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         8    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         8    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       5/2    0.000    0.000    0.007    0.003 {method 'run' of '_contextvars.Context' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#       5/2    0.000    0.000    0.007    0.003 events.py:82(_run)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         5    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         5    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#       4/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         4    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         4    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         3    0.000    0.000    0.007    0.002 base_events.py:1894(_run_once)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         3    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         3    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         3    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       2/1    0.000    0.000    0.108    0.108 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.005    0.003 socket.py:703(send_multipart)
#       2/1    0.000    0.000    0.000    0.000 selectors.py:451(select)
#         2    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.006    0.003 zmqstream.py:624(_handle_recv)
#         2    0.000    0.000    0.007    0.003 zmqstream.py:583(_handle_events)
#         2    0.000    0.000    0.000    0.000 iostream.py:655(write)
#         2    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         2    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         2    0.000    0.000    0.006    0.003 iostream.py:157(_handle_event)
#         2    0.001    0.000    0.006    0.003 iostream.py:276(<lambda>)
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         2    0.000    0.000    0.005    0.003 iostream.py:278(_really_send)
#         2    0.019    0.010    0.031    0.015 {method '__exit__' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         2    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.006    0.003 zmqstream.py:556(_run_callback)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#       2/1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         2    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         2    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:427(flush)
#         1    0.000    0.000    0.031    0.031 history.py:845(writeout_cache)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         1    0.037    0.037    0.064    0.064 1140210951.py:2(create_array)
#         1    0.000    0.000    0.067    0.067 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 1140210951.py:8(print_statement)
#         1    0.003    0.003    0.067    0.067 1140210951.py:12(main)
#         1    0.000    0.000    0.007    0.007 asyncio.py:200(_handle_events)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:324(_flush)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#         1    0.004    0.004    0.041    0.041 decorator.py:229(fun)
#         1    0.000    0.000    0.031    0.031 history.py:833(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         1    0.000    0.000    0.037    0.037 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:659(_check_closed)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:468(update_flag)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 base_events.py:717(is_closed)
#         1    0.000    0.000    0.000    0.000 poll.py:31(register)
#         1    0.000    0.000    0.000    0.000 poll.py:80(poll)
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 base_events.py:835(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 threading.py:1153(_wait_for_tstate_lock)

# %%
cProfile.run("main()", sort="ncalls", filename="profile.txt")  # Order is ncalls
# Out:
# Array created successfully

# %%
# !cat profile.txt
# Out:
# r=)rrg�QT��_�>g�QT��_�>�r1i��__subclasscheck__)rrg�g�L�>g�g�L�>��//usr/local/python/3.12.1/lib/python3.12/enum.pyi��__or__)�rGg�o�&���>g�o�&���>�rEi�__and__)�jects>)iD/iD/g����-߃?g����-߃?0)rr�#<method 'extend' of 'list' objects>)rrgP�-�?�>gP�-�?�>{��[/workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.pyi��_notify_observers)rrgP�-�?�>gP�-�?�>0)rr� <method 'get' of 'dict' objects>)�rg�����>g�����>{r)rrg�����>g�����>0)rr�"<method 'items' of 'dict' objects>)rrg����U�>g����U�>{��Z/workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.pyi��write)rrg����U�>g����U�>0)rr�!<method 'upper' of 'str' objects>)r	r	gt.F�z��>gt.F�z��>{��[/workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/sugar/attrsettr.py�+�__getattr__)r	r	gt.F�z��>gt.F�z��>0)rr�"<built-in method builtins.getattr>)r	r	gA����>gA����>{r")r	r	gA����>gA����>0)rr�"<built-in method builtins.hasattr>)r(g�wI$��>g�wI$��>{��<frozen importlib._bootstrap>in�_handle_fromlist)r	r	g	ʧ��#�>g	ʧ��#�>�ri��_cross_validate)rrg�H�!�>g�H�!�>r)rrg*8@Y���>g*8@Y���>�ri��	_validate)rrge�V�S�>ge�V�S�>0)rr�<built-in method builtins.hash>)rrgA�|�>gA�|�>{)�1/usr/local/python/3.12.1/lib/python3.12/typing.pyi�__hash__)rrgA�|�>gA�|�>0)rr�%<built-in method builtins.isinstance>)�B�Fg�kS`�!�>g���3΃?{r))r	r	g>ވG�>g>ވG�>��X/workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/sugar/socket.pyi��send_multipart)�r9g�nH��>g�nH��>r)rrg�A:�ŉ>g�A:�ŉ>r)rrg��/n��>g��/n��>�ri/�set)rrgL(��H�>gL(��H�>�ri	validate)rrg�z�]ʒ>g�z�]ʒ>��_/workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.pyi,�
# _handle_event)rrgTo�!��>gTo�!��>)�0/usr/local/python/3.12.1/lib/python3.12/queue.py���_qsize)rrg����;�>g����;�>�ri(�validate_elements)rrg�a삖��>g�a삖��>0)rr�<built-in method builtins.max>)r	r	g;��/���>g;��/���>{rO)rrg�|,�i�>g�|,�i�>rR)rrg���|6��>g���|6��>0)rr�<built-in method builtins.min>)rrg�CY���>g�CY���>{rR)rrg�CY���>g�CY���>0)rr�<built-in method builtins.next>)�r`g��DV�B�>g��DV�B�>{r)r`r`g��DV�B�>g��DV�B�>0)rr� <built-in method builtins.print>)rrgA����>g� s
# ��?{)rr(�print_statement)rrgA����>g� s
# parent_header)rrgOPgG�(�>gOPgG�(�>0)rr�<built-in method posix.getpid>)rrg�2�|��>g�2�|��>{)ri&�_is_master_process)rrg�O���>g�O���>)r��rj)rrgX��)��>gX��)��>0)rr�0<method 'append' of 'collections.deque' objects>)r	r	g=zh�q��>g=zh�q��>{�rischedule)rrg�j��R�>g�j��R�>�rSi+�
# _release_save)rrg��k�u�>g��k�u�>0)rr�.<method '__enter__' of '_thread.lock' objects>)rrg�SAY���>g�SAY���>{)rui+�	__enter__)rrg�SAY���>g�SAY���>0)rr�-<method '__exit__' of '_thread.lock' objects>)r`r`g���j�>g���j�>{��\/workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/IPython/core/history.pyiM�writeout_cache)rrg���|6��>g���|6��>�rX�a�empty)rrgL��H�>gL��H�>)rui.__exit__)rrg�PП��>g�PП��>0)rr� <built-in method time.monotonic>)rrg!��o�>g!��o�>{)rSi��time)rrg!��o�>g!��o�>0)rr�)<built-in method _abc._abc_subclasscheck>)rrggz>BN�>ggz>BN�>{)�<frozen abc>�yrC)rrggz>BN�>ggz>BN�>0)r�r�rC)rrg#�$�v��>gŎO���>{)rrrK)rrg#�$�v��>gŎO���>0)r*inr+)r	r	gwp���/�>gn��;�4�>{r")r	r	gwp���/�>gn��;�4�>0)rEi\�__new__)�r�g�m� �>g�m� �>{)rEi�__call__)r�r�g�m� �>g�m� �>0)r7i�r8)rrg�}P�a8?g
# X�1"?{�ri�_really_send)rrg�}P�a8?g
# ?rm)rrg%��x;�>g%��x;�>0)rPi�rQ)rrg������>g,�wA&�>{rR)rrg������>g,�wA&�>0)r#r$r%)r	r	gsMDi���>gMK?�?{�r?iG�_handle_events)rrg
# r\)rrg樜)�A�>gQ�؎��>{r[)rrg樜)�A�>gQ�؎��>0)r?ipr�)rrg�X͑��>g{����t�>{r�)rrg�X͑��>g{����t�>0)r?iGr�)rrg̮gG+p�>g��~�	��?{)ri��bind)rrg�ˍ�Of�>gH<	��?0)ri�r;)rrg��Pӣ��>g�[x�F�?{r:)rrg��Pӣ��>g�[x�F�?0)�B/usr/local/python/3.12.1/lib/python3.12/asyncio/selector_events.pyi��_process_events)rrg���+o�>g���+o�>{rR)rrg���+o�>g���+o�>0)riu�get)r`r`gA���s�>gI���>{�ri��__get__)r`r`gA���s�>gI���>0)ri�r-)rrgV�&hc��>g�r5:��>{r.)rrgV�&hc��>g�r5:��>0)ri�r)rrg�7t>2��>g3ߖϿK�>{)ri��
# �?{)r?i�<lambda>)rrg̮gG+p�>g��~�
# �?0)riMr�)rrg�5�oE��>gJ���{�?{�r�7�only_when_enabled)rrg�5�oE��>gJ���{�?0)ri�r )rrgE�H�?g!$
# 4?{)rrra)rrgE�H�?g!$
# 4?0)r��_event_pipe)rrgR>�)�4�>gR>�)�4�>{rm)rrgR>�)�4�>gR>�)�4�>0)ri�rh)rrgz��
# �>g��q����>{r)rrgz��
# �F�?g�qi{B�?{�r��main)rrgg0)<string>r<module>)rrg	R���>g�Q���?{0)rr(rb)rrg<���i�>gI�h%� ?{0)rr�r�)rrg)��di?g��J��?{�r�rr�)rrgg0)ri&rj)rrg�n7ߍ��>ge��c�U�>{r)rrg�n7ߍ��>ge��c�U�>0)riA�_schedule_flush)rrgc
# >`�>g-ᇅ�S	?{r)rrgc
# >`�>g-ᇅ�S	?0)rrkrj)rrg��"��>g�(� 0�>{)r���_check_mp_mode)rrg��"��>g�(� 0�>0)rrVrW)rrg�ju~���>gełX��'?{r>)rrg�ju~���>gełX��'?0)ri<lambda>)rrg�>�����>g�A���%?{rU)rrg�>�����>g�A���%?0)r���closed)rrg0���:=�>g0���:=�>{r�)rrg0���:=�>g0���:=�>0)rr�r�)rrg
# �`ʃ��>g����?�>{r�)rrg
# ��?{0)r?i�r�)rrg��t���>g��m�П?{�r?i��_rebuild_io_state)rrg��t���>g��m�П?0)r?i�r�)rrg��6�>g?7_�?{)�V/workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/ioloop.pyi�r@)rrg��6�>g?7_�?0)�V/workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/dateutil/tz/tz.py�J�	utcoffset)rrgةs�8�>gةs�8�>{r)rrgةs�8�>gةs�8�>0)rr�2<method 'execute' of 'sqlite3.Connection' objects>)rrg6��`~)?g6��`~)?{�riAr�)rrg6��`~)?g6��`~)?0)rrr)rrg�]q�qk�?g����O%�?{r�)rrg��"�j�?gBR/�rof.Profiler' objects>)rrgb�C
# r=)rrgIqV��9�>g.R�C��>{r.)rrgIqV��9�>g.R�C��>0)rr�+<built-in method _asyncio.get_running_loop>)rrg�O���>g�O���>{�r�r�r�)rrg�O���>g�O���>0)rr�+<built-in method _contextvars.copy_context>)rrg�S�.��>g�S�.��>{�rd� __init__)rrg�S�.��>g�S�.��>0)ri�5�Mt?0)ri	r=)rrg��%e���>g*��u:(�>{rA)rrg��%e���>g*��u:(�>0)ri�r�)rrg)����>g����J�>{�ri�r;)rrg)����>g����J�>0)ri(r\)rrg"Eo����>g?���ˣ�>{rA)rrg"Eo����>g?���ˣ�>0)r?i,r@)rrgq�_�
# �name)rrg$6_�-�>g$6_�-�>{r)rrg$6_�-�>g$6_�-�>0)ri�
# �kind)rJrJgR<ܦ)�>gR<ܦ)�>{r
# )rrgg�>gg�>r)rrg�|�/�#�>g�|�/�#�>r)rrgs7*e�6�>gs7*e�6�>0)ri:r�)rrg+�NSf��>g+�NSf��>{r)rrg+�NSf��>g+�NSf��>0)ri�
# parameters)rrg�%#��d�>g�%#��d�>{r
# hG|��>gu����>r)rrg�����U�>gr2��~��>)r#r4r�)r	r	g?�̔���>g>}	��\�>rD)r9r9gb7��4��>g���x&��>rH)�r�gLLJS�S�>g`toE��>0)r1i�rC)rrgR<ܦ)�>gT�?,��>{)r1i�r�)rrgR<ܦ)�>gT�?,��>0)rui�rx)rrgP�-�?�>g�,b��>{r�)rrgP�-�?�>g�,b��>0)rEi�rF)r9r9g����??g��8��?{r6)r�r�g�x'���>goR�?r�)rrg���B��>g�����>0)rEirI)r�r�g>�l�g�>gKm�����>{r�)rrg�&DV=��>g5�>Y���>r�)rrg]O��'|�>g��T���>r�)rrg��n�>gJ�x[�>00s*�>gf�ǔh��>{0)rSir�)rrg�a�#��>g�b���>{r�)rrg�a�#��>g�b���>0)rui+r|)rrg��q�V_�>g�	�Y�>{�ruisr�)rrg'�t3*�>gz����>0)rui.r�)rrg�h"�?ֹ>g~H��}�>{rR)rrg<?�.d�>g#�$�vɴ>r�)rrg���"�>g�%#��d�>0)rui4rz)rrg��`��>gD�n�l�>{0)rui7rw)rrg9�q���>g�%#��d�>{rO)rrg9�q���>g�%#��d�>0)r#r4�

# %% [markdown]
# ### Profiling multiple functions or methods together

# %%
def using_range(nums):
    successive_diffs = []
    for i in range(len(nums)):
        if i == 0:
            continue
        successive_diffs.append(nums[i - 1] - nums[i])
    return successive_diffs


def using_enumerate(nums):
    successive_diffs = []
    for i, num in enumerate(nums):
        if i == 0:
            continue
        successive_diffs.append(nums[i - 1] - nums[i])
    return successive_diffs

# %%
cProfile.run("using_range(range(10000))")
# Out:
#          10004 function calls in 0.006 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.004    0.004    0.005    0.005 3792339585.py:1(using_range)
#         1    0.000    0.000    0.005    0.005 <string>:1(<module>)
#         1    0.000    0.000    0.006    0.006 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#      9999    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
cProfile.run("using_enumerate(range(10000))", sort=True)
# Out:
#          10469 function calls (10459 primitive calls) in 0.007 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003    0.004    0.004 3792339585.py:10(using_enumerate)
#     10004    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#         4    0.001    0.000    0.006    0.001 base_events.py:1894(_run_once)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:276(<lambda>)
#        14    0.000    0.000    0.000    0.000 socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       4/2    0.000    0.000    0.001    0.000 {method 'run' of '_contextvars.Context' objects}
#         5    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#        15    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         2    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#        29    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#     70/66    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.004    0.004 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 socket.py:703(send_multipart)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#        29    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         7    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         3    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         2    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:556(_run_callback)
#         1    0.000    0.000    0.004    0.004 history.py:55(only_when_enabled)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#       4/2    0.000    0.000    0.001    0.000 events.py:82(_run)
#         3    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:583(_handle_events)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#       2/1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#       2/1    0.000    0.000    0.000    0.000 selectors.py:451(select)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         2    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.004    0.004 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:624(_handle_recv)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         1    0.000    0.000    0.004    0.004 decorator.py:229(fun)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#         2    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         3    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         3    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         8    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:835(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         3    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         6    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         4    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.001    0.001 asyncio.py:200(_handle_events)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#        10    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         5    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         1    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         5    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         3    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         1    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:717(is_closed)

# %%
cProfile.run("using_range(range(10000));using_enumerate(range(10000))", sort=True)
# Out:
#          20589 function calls (20582 primitive calls) in 0.077 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.028    0.014    0.019    0.019 {built-in method builtins.exec}
#         2    0.026    0.013    0.027    0.014 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.012    0.012    0.017    0.017 3792339585.py:10(using_enumerate)
#     20004    0.007    0.000    0.007    0.000 {method 'append' of 'list' objects}
#         1    0.001    0.001    0.002    0.002 3792339585.py:1(using_range)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       5/4    0.000    0.000    0.047    0.012 base_events.py:1894(_run_once)
#         1    0.000    0.000    0.019    0.019 <string>:1(<module>)
#        14    0.000    0.000    0.000    0.000 socket.py:626(send)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 socket.py:703(send_multipart)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#     81/77    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        16    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         2    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#        31    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#         1    0.000    0.000    0.028    0.028 history.py:845(writeout_cache)
#         3    0.000    0.000    0.000    0.000 selectors.py:451(select)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         8    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:583(_handle_events)
#         5    0.000    0.000    0.001    0.000 {method 'run' of '_contextvars.Context' objects}
#        31    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         8    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:324(_flush)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.028    0.028 history.py:833(_writeout_input_cache)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         4    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         2    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         1    0.000    0.000    0.000    0.000 poll.py:80(poll)
#         8    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         3    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         5    0.000    0.000    0.001    0.000 events.py:82(_run)
#         2    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:624(_handle_recv)
#         2    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         3    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:427(flush)
#         4    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         2    0.000    0.000    0.000    0.000 iostream.py:276(<lambda>)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         5    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:556(_run_callback)
#       2/1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         1    0.000    0.000    0.028    0.028 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         1    0.000    0.000    0.028    0.028 decorator.py:229(fun)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         1    0.000    0.000    0.000    0.000 asyncio.py:200(_handle_events)
#         2    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         8    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         9    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         4    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#        28    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         2    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 base_events.py:835(call_soon_threadsafe)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         5    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         4    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:468(update_flag)
#         1    0.000    0.000    0.000    0.000 poll.py:31(register)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         5    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         3    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:659(_check_closed)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:717(is_closed)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}

# %% [markdown]
# ### Comparing two functions

# %%
cProfile.runctx(
    "using_range(range(10000))", globals(), locals(), sort="time"
)  # filename='profile1.txt')
cProfile.runctx(
    "using_enumerate(range(10000))", globals(), locals(), sort="time"
)  # filename='profile2.txt')
# Out:
#          10512 function calls (10502 primitive calls) in 0.017 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.011    0.011    0.014    0.014 3792339585.py:1(using_range)
#     10005    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#         1    0.001    0.001    0.001    0.001 {method 'execute' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#        14    0.000    0.000    0.000    0.000 socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.001    0.000 socket.py:703(send_multipart)
#       6/4    0.000    0.000    0.002    0.000 events.py:82(_run)
#        16    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#       6/4    0.000    0.000    0.002    0.000 {method 'run' of '_contextvars.Context' objects}
#         5    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#        31    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#         4    0.000    0.000    0.018    0.004 base_events.py:1894(_run_once)
#       3/2    0.000    0.000    0.000    0.000 selectors.py:451(select)
#     74/70    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.001    0.000 iostream.py:278(_really_send)
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         8    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         1    0.000    0.000    0.014    0.014 <string>:1(<module>)
#        31    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         1    0.000    0.000    0.000    0.000 poll.py:80(poll)
#         4    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         2    0.000    0.000    0.001    0.001 zmqstream.py:624(_handle_recv)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         3    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:324(_flush)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:427(flush)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         2    0.000    0.000    0.001    0.001 zmqstream.py:583(_handle_events)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#       2/1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         6    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         2    0.000    0.000    0.001    0.000 iostream.py:157(_handle_event)
#         2    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         3    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.014    0.014 {built-in method builtins.exec}
#         6    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         2    0.000    0.000    0.001    0.000 iostream.py:276(<lambda>)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 base_events.py:835(call_soon_threadsafe)
#         3    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:468(update_flag)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         4    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:556(_run_callback)
#         5    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         1    0.000    0.000    0.001    0.001 asyncio.py:200(_handle_events)
#         2    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         2    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#         9    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         5    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         4    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         2    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#        14    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         1    0.000    0.000    0.000    0.000 poll.py:31(register)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         5    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         3    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:659(_check_closed)
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 base_events.py:717(is_closed)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#
#
#          10075 function calls in 0.004 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      9999    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#         1    0.002    0.002    0.002    0.002 3792339585.py:10(using_enumerate)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.002    0.002 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.002    0.002 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}

# %% [markdown]
# ### Profiling with line-by-line analysis

# %%
def create_array():
    arr = []
    for i in range(0, 400000):
        arr.append(i)


def print_statement():
    print("Array created successfully")


def main():
    create_array()
    print_statement()


if __name__ == "__main__":
    import cProfile
    import pstats

    profiler = cProfile.Profile()
    profiler.enable()
    main()
    profiler.disable()

    stats = pstats.Stats(profiler).sort_stats("ncalls")
    stats.print_stats()
# Out:
# Array created successfully
#          400620 function calls (400613 primitive calls) in 0.102 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    400006    0.041    0.000    0.041    0.000 {method 'append' of 'list' objects}
#     83/79    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        31    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/enum.py:1116(__new__)
#        31    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/enum.py:713(__call__)
#        28    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/typing.py:2119(cast)
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        16    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/enum.py:1531(__or__)
#        15    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/sugar/socket.py:626(send)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        10    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2794(kind)
#         9    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         9    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:629(get)
#         8    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:676(__get__)
#         8    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/enum.py:1541(__and__)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         6    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/typing.py:378(inner)
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         5    0.000    0.000    0.001    0.000 {method 'run' of '_contextvars.Context' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         5    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/sugar/attrsettr.py:43(__getattr__)
#         5    0.000    0.000    0.001    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/events.py:82(_run)
#         5    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:538(receiving)
#         5    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:1989(get_debug)
#         5    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:731(time)
#         5    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/sugar/attrsettr.py:66(_get_attr_opt)
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#       4/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/selector_events.py:746(_process_events)
#         4    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:542(sending)
#         4    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/queue.py:97(empty)
#         4    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/queue.py:209(_qsize)
#         4    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2782(name)
#         4    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:3075(parameters)
#         4    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/typing.py:1239(__hash__)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/selectors.py:451(select)
#         3    0.000    0.000    0.001    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:1894(_run_once)
#         3    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:686(_update_handler)
#         3    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:663(_rebuild_io_state)
#         3    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/events.py:32(__init__)
#         3    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:537(_check_closed)
#         3    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:811(_call_soon)
#         3    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:299(__enter__)
#         3    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:302(__exit__)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/sugar/socket.py:703(send_multipart)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/sugar/socket.py:774(recv_multipart)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:689(set)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:624(_handle_recv)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:583(_handle_events)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:655(write)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:505(parent_header)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/queues.py:322(_consume_expired)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:550(_is_master_process)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:577(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:213(_is_master_process)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:157(_handle_event)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:276(<lambda>)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:255(closed)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:216(_check_mp_mode)
#       2/1    0.000    0.000    0.025    0.025 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/decorator.py:229(fun)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:278(_really_send)
#         2    0.015    0.007    0.025    0.012 {method '__exit__' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:3631(set)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/ioloop.py:742(_run_callback)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:556(_run_callback)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:718(_validate)
#       2/1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:1879(_add_callback)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/typing.py:1175(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:782(call_soon)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/concurrent/futures/_base.py:537(set_result)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2905(kwargs)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2882(args)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:3119(_bind)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:427(flush)
#         1    0.000    0.000    0.025    0.025 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/IPython/core/history.py:845(writeout_cache)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py:225(add_callback)
#         1    0.041    0.041    0.071    0.071 /tmp/ipykernel_5368/267384398.py:1(create_array)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_5368/267384398.py:7(print_statement)
#         1    0.003    0.003    0.074    0.074 /tmp/ipykernel_5368/267384398.py:11(main)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py:200(_handle_events)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/queues.py:225(get)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/queues.py:186(put)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:302(poll_control_queue)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:324(_flush)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/queues.py:317(__put_internal)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/ipykernel/iostream.py:259(schedule)
#         1    0.000    0.000    0.025    0.025 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/IPython/core/history.py:833(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/IPython/core/history.py:839(_writeout_output_cache)
#         1    0.000    0.000    0.025    0.025 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/IPython/core/history.py:55(only_when_enabled)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/decorator.py:199(fix)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:659(_check_closed)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:694(<lambda>)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/dateutil/tz/tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/tornado/concurrent.py:182(future_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:468(update_flag)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/traitlets/traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/selector_events.py:141(_write_to_self)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:424(notify_all)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/concurrent/futures/_base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:717(is_closed)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/sugar/poll.py:31(register)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/.venv/lib/python3.12/site-packages/zmq/sugar/poll.py:80(poll)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/futures.py:394(_call_set_state)
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:835(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.074    0.074 /usr/local/python/3.12.1/lib/python3.12/threading.py:637(wait)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:1220(is_alive)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:1153(_wait_for_tstate_lock)

# %%
# Export profiler output to file
stats = pstats.Stats(profiler)
stats.dump_stats("export-data.txt")

# %% [markdown]
# ### Profiling memory usage
#
#
#     pip install memory_profiler

# %%
cProfile.runctx("using_range(range(10000))", globals(), locals(), sort="time")
# Out:
#          10004 function calls in 0.005 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.004    0.004    0.005    0.005 3792339585.py:1(using_range)
#      9999    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.005    0.005 {built-in method builtins.exec}
#         1    0.000    0.000    0.005    0.005 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}

# %%
from memory_profiler import memory_usage


nums = tuple(range(1000))
memory_profiler = memory_usage((using_range, (nums,), {}))
print("Memory usage:", memory_profiler[0])
# Out:
# Memory usage: 84.39453125
